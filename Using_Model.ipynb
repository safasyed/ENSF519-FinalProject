# %%
import numpy as np
import pandas as pd
import nltk
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import re, string
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.preprocessing import sequence
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer

from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model

# %%
#Create dataframe from csv data
df = pd.read_csv('export_dataframe.csv', error_bad_lines=False, na_values=['nan'])
text = df['Synopsis']
target = df['Summary']

# %%
#Create the dataframe we are working with and drop some nan rows
df = pd.DataFrame({'Synopsis':text, 'Summary':target}, dtype='str')

df=df[df.Summary != 'nan']
df
# Out:
#                                                 Synopsis                                            Summary
# 0      The unforgettable novel of a childhood in a sl...            harper lee consid book simpl love story
# 1      The year 1984 has come and gone, but George Or...  deni novel hold imagin generations power admon...
# 2      Alternate Cover Edition ISBN: 0743273567 (ISBN...  stori fabul wealthi jay gatsbi new love beauti...
# 3      Harry Potter's life is miserable. His parents ...                        harri potter life miserable
# 4      George Orwell's timeless and timely allegorica...   anim farm published stalinist russia seen target
# ...                                                  ...                                                ...
# 9996   Ballu  is a gangster who is arrested by Inspec...  ram show compass ballu tri provid inform lead ...
# 9997   The central figure of the film is represented ...               scienc use brain art use brain heart
# 9998   Set in 2003, Huck Cheever  is a young and tale...  billi older sister suzann warn huck hustl 10 c...
# 9999   The Namesake depicts the struggles of Ashoke a...    short after gogol vacat maxin family ashok dies
# 10000  Bobby Taylor ([[Robert Townsend  is a middle c...  practic line bathroom younger brother stevi wa...
#
# [9606 rows x 2 columns]

# %%
#Method for cleaning the synopsis text data
def clean_text(text):
    text = str(text)
    text = text.lower()
    text = re.sub('\s+', ' ', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = ' '.join([w for w in text.split() if w not in ENGLISH_STOP_WORDS])
    return text

df['Synopsis'] = df['Synopsis'].apply(clean_text)

# %%
#method for cleaning summary text data
def clean_title(title):
    title = str(title)
    title = title.lower()
    title = re.sub('\s+', ' ', title)
    title = title.translate(str.maketrans('', '', string.punctuation))
    title = ' '.join([w for w in title.split() if w not in ENGLISH_STOP_WORDS])
    return title

df['CleanTitle'] = df['Summary'].apply(clean_title)
df['CleanTitle'] = df['CleanTitle'].apply(lambda x : '_START_ '+ x + ' _END_')
print(df['CleanTitle'])
# Out:
# 0        _START_ harper lee consid book simpl love stor...
# 1        _START_ deni novel hold imagin generations pow...
# 2        _START_ stori fabul wealthi jay gatsbi new lov...
# 3                _START_ harri potter life miserable _END_
# 4        _START_ anim farm published stalinist russia s...
#                                ...
# 9996     _START_ ram compass ballu tri provid inform le...
# 9997     _START_ scienc use brain art use brain heart _...
# 9998     _START_ billi older sister suzann warn huck hu...
# 9999     _START_ short gogol vacat maxin family ashok d...
# 10000    _START_ practic line bathroom younger brother ...
# Name: CleanTitle, Length: 9606, dtype: object

# %%
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(df['Synopsis'])

#Some globals required for later
latentdim = 500
max_text_length = 125
max_target_length = 20

#convert each sentence into an array of integer representations for the words
x_tr    =   x_tokenizer.texts_to_sequences(df['Synopsis']) 

#we are padding 0 here to the sequence so they are all the same size sequence
x_tr    =   sequence.pad_sequences(x_tr,  maxlen=max_text_length, padding='post') 

#Repeat the same as above but in the Y set
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(df['CleanTitle'])

y_tr = y_tokenizer.texts_to_sequences(df['CleanTitle'])

y_tr = sequence.pad_sequences(y_tr, maxlen=max_target_length, padding='post')


#xtr = x_tr.reshape(x_tr.shape[0],x_tr.shape[1],1)
#ytr = y_tr.reshape(y_tr.shape[0],y_tr.shape[1],1)

# %%
# Load in the pretrained model output by Training_Model.ipynb
from keras.models import load_model
model = load_model('model.h5')
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 125)          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 125, 500)     48378000    input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 500)    18539000    input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 125, 500), ( 2002000     embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 500),  2002000     embedding_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 37078)  18576078    lstm_2[0][0]
# ==================================================================================================
# Total params: 89,497,078
# Trainable params: 89,497,078
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
dec_inputs = Input(shape=(None,))

# Grab the encoder part of the model and put it into one model
enc_model = Model(inputs=model.layers[0].input, outputs=model.layers[4].output)

# Setting up the input dimensions of states
dec_state_in_h = Input(shape=(latentdim,))
dec_state_in_c = Input(shape=(latentdim,))
dec_hidden_in = Input(shape=(max_text_length,latentdim))

# Grab the decodin embedding layer and initiliaze its dimensions
dec_emb = model.layers[3]
dec_emb_pred = dec_emb(dec_inputs)

# Grab the LSTM from the decoding part of the model
dec_lstm = model.layers[5]

# Get the states of the decoder LSTM
out, state_h, state_c = dec_lstm(dec_emb_pred, initial_state=[dec_state_in_h, dec_state_in_c])

# Grab the Dense layer of the model
dec_dense = model.layers[6]
out = dec_dense(out)

# Grab the encoder part of the original model and combine it into one model so we can use it
dec_model = Model([dec_inputs] + [dec_hidden_in,dec_state_in_h, dec_state_in_c], [out, state_h, state_c])

# %%
# Maps for index to word
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
def decode_sequence(input_seq):
    # Get the starting sequences from encoding layer model
    e_out, e_h, e_c = enc_model.predict(input_seq)
    # Generate an emtpy value to store target seq
    target_seq = np.zeros((1,1))

    # Use the added start word to tell where the target starts
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        # Here we get the predicition and states from the model
        output_tokens, h, c = dec_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        # If we predict a zero value we consider the summary finished so return
        if sampled_token_index == 0:
          return decoded_sentence

        # Do a lookup for the word that the predicted integer represents  
        sampled_token = reverse_target_word_index[sampled_token_index]

        # Add the word onto the sentence
        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

            # Our main exit condition is if we predict the end of the summary or hit max length of a summary
            if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_target_length-1)):
                stop_condition = True

        #update the cursor for the next word
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        #New states for the next word
        e_h, e_c = h, c

    return the 
    return decoded_sentence

# %%
#Converts a sequence into the summary it was originally
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString
#Converts a sequence into the synopsis it was originally
def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
#Looping through all words and adding them to a dictionary for export
new_df = {'Synopsis':[], 'Extracted Summary':[], 'Abstracted Summary': [] }
for i in range(len(x_tr)):
    print("Synopsis:",seq2text(x_tr[i]))
    new_df['Synopsis'].append(seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    new_df['Extracted Summary'].append(seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_length)))
    new_df['Abstracted Summary'].append(decode_sequence(x_tr[i].reshape(1,max_text_length)))
    print("\n")
# Out:
# Synopsis: unforgettable novel childhood sleepy southern town crisis conscience rocked kill mockingbird instant bestseller critical success published 1960 went win pulitzer prize 1961 later academy awardwinning film classiccompassionate dramatic deeply moving kill mockingbird takes readers roots human behavior innocence experience kindness cruelty love hatred humor pathos 18 million copies print translated languages regional story young alabama woman claims universal appeal harper lee considered book simple love story today regarded masterpiece american literature
# Original summary: harper lee consid book simpl love story
# Predicted summary:  movi lesson live life live hari aarthi deaf mute
#
#
# Synopsis: year 1984 come gone george orwells prophetic nightmarish vision 1949 world timelier 1984 great modern classic negative utopia—a startlingly original haunting novel creates imaginary world completely convincing sentence words deny novels hold imaginations generations power admonitions—a power grow lessen passage time
# Original summary: deni novel hold imagin generations power admonitions—a power grow lessen passag time
# Predicted summary:  volum includes time north america hartley introduct novel
#
#
# Synopsis: alternate cover edition isbn 0743273567 isbn13 9780743273565the great gatsby f scott fitzgeralds book stands supreme achievement career exemplary novel jazz age acclaimed generations readers story fabulously wealthy jay gatsby new love beautiful daisy buchanan lavish parties long island time new york times noted gin national drink sex national obsession exquisitely crafted tale america 1920sthe great gatsby great classics twentiethcentury literatureback cover
# Original summary: time note gin nation drink sex nation obsession exquisit craft tale america 1920sthe great gatsbi great classic twentiethcenturi literature
# Predicted summary:  humbl wang lung glori soil works nurtur land nurtur family
#
#
# Synopsis: harry potters life miserable parents dead hes stuck heartless relatives force live tiny closet stairs fortune changes receives letter tells truth hes wizard mysterious visitor rescues relatives takes new home hogwarts school witchcraft wizardryafter lifetime bottling magical powers harry finally feels like normal kid wizarding community special boy lived person survived killing curse inflicted evil lord voldemort launched brutal takeover wizarding world vanish failing kill harrythough harrys year hogwarts best life perfect dangerous secret object hidden castle walls harry believes responsibility prevent falling evil hands doing bring contact forces terrifying imaginedfull sympathetic characters wildly imaginative situations countless exciting details installment series assembles unforgettable magical world sets stage highstakes adventures come
# Original summary: harri potter life miserable
# Predicted summary:  featur worldfam masterpiece death venice new collect nobel laureat thoma mann stori novella reveal artist evolution
#
#
# Synopsis: george orwells timeless timely allegorical novel—a scathing satire downtrodden society’s blind march totalitarianism“all animals equal animals equal others”a farm taken overworked mistreated animals flaming idealism stirring slogans set create paradise progress justice equality stage set telling satiric fables penned—a razoredged fairy tale grownups records evolution revolution tyranny totalitarianism just terrible animal farm published stalinist russia seen target today devastatingly clear freedom attacked banner cutting clarity savage comedy george orwell’s masterpiece meaning message ferociously fresh
# Original summary: anim farm published stalinist russia seen target
# Predicted summary:  famili thing quit way bomb continu drop surviv bring closer togetherfamili eventu thamessid home grace parent hous burn
#
#
# Original summary: english translat author aleksandr solzhenitsyn publish soviet journal novi mir 1962 day life ivan denisovich stand classic contemporari literature
# Predicted summary:  obsess irresist fascin enigmat sarah charl hurtl moment consumm lust brink existenti void
#
#
# Synopsis: year 1945 claire randall combat nurse just war reunited husband second honeymoon walks standing stone ancient circles dot british isles suddenly sassenach—an “outlander”—in scotland torn war raiding border clans year lord1743 hurled time forces understand claire catapulted intrigues lairds spies threaten life shatter heart james fraser gallant young scots warrior shows love absolute claire woman torn fidelity desire—and vastly different men irreconcilable lives
# Original summary: 1945 clair randall combat nurse just war reunit husband second honeymoon walk stand stone ancient circl dot british isles
# Predicted summary:  volum includes time north america hartley introduct novel
#
#
# Synopsis: librarians note alternate cover edition herea bold english adventurer invincible japanese warlord beautiful woman torn ways life ways love brought extraordinary saga time place aflame conflict passion ambition lust struggle power
# Original summary: beauti woman torn way life way love
# Predicted summary:  volum sandman collect seri short comic book stories
#
#
# Synopsis: compassionate realism narrative sweep recall work charles dickens magnificent novel captures cruelty corruption dignity heroism india time 1975 place unnamed city sea government just declared state emergency upheavals strangersa spirited widow young student uprooted idyllic hill station tailors fled caste violence native villagewill thrust forced share cramped apartment uncertain future characters distrust friendship friendship love fine balance creates enduring panorama human spirit inhuman state
# Original summary: charact distrust friendship friendship love fine balanc creat endur panorama human spirit inhuman state
# Predicted summary:  volum includes time north america hartley introduct novel
#
#
# Synopsis: matilda little girl far good true age fiveandahalf shes knocking doubledigit multiplication problems blitzreading dickens remarkably classmates love shes supernerd teachers pet perfect matildas world starters idiotic selfcentered parents lived theres large busty nightmare school principal miss trunchbull hammerthrowing champion flings children approximately sympathetic bulldozer fortunately matilda inner resources deal annoyances astonishing intelligence saintly patience innate predilection revengeshe warms practical jokes aimed hapless parents true test comes rallies defense teacher sweet miss honey diabolical trunchbull doubt matilda carry day wonderful story far predictable roald dahl keeping plot moving imaginatively unerring ear emotional truth reader cares matilda addition gifts real feelings
# Original summary: perfect matilda world
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-53e3ad820507> in <module>()
#       5     print("Original summary:",seq2summary(y_tr[i]))
#       6     new_df['Extracted Summary'].append(seq2summary(y_tr[i]))
# ----> 7     print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_length)))
#       8     new_df['Abstracted Summary'].append(decode_sequence(x_tr[i].reshape(1,max_text_length)))
#       9     print("\n")
#
# <ipython-input-57-ad12d51f8625> in decode_sequence(input_seq)
#       1 def decode_sequence(input_seq):
#       2     # Get the starting sequences from encoding layer model
# ----> 3     e_out, e_h, e_c = enc_model.predict(input_seq)
#       4     # Generate an emtpy value to store target seq
#       5     target_seq = np.zeros((1,1))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1399                                             verbose=verbose,
#    1400                                             steps=steps,
# -> 1401                                             callbacks=callbacks)
#    1402
#    1403     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     330             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     331             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 332             batch_outs = f(ins_batch)
#     333             batch_outs = to_list(batch_outs)
#     334             if batch_index == 0:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#Create dataframe and export to csv for topic modelling
ndf = pd.DataFrame.from_dict(new_df)
ndf
ndf.to_csv('all_summaries.csv', index=False)
